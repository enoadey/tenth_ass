# %% [markdown]
# # CIFAR Classification
#
# ### Exercise objectives
#
# - Implement a CNN for a 10-class classification problem
# - Enhance the CNN performance with data augmentation techniques
# - Experiment the acceleration of GPU for image processing (Google Colab)
#
# <hr>
# <hr>
#
# You should now have a better feeling of how a CNN is working, and especially how the convolutions are affecting the image to detect specific features. Therefore, let's now play with a bit more complex images.
#
# The CIFAR-10 dataset is a dataset that contains images of 10 different classes
#
# <img src="https://people.minesparis.psl.eu/fabien.moutarde/ES_MachineLearning/mini-projets/cifar10_notebook_fichiers/cifar_10.png">
#
# This dataset is emblematic in the research community as many enhancements for image problems have been achieved on this dataset, and later on the CIFAR-100 dataset once the performance got too high. You can check the [wikipedia](https://en.wikipedia.org/wiki/CIFAR-10) page of the dataset if you want to know more about it.
#
# In this notebook, we propose to implement a CNN to distinguish the 10 categories from the CIFAR-10 dataset. Again, remember that until 10 years ago, this problem was very challenging to the entire research community and is now for you to tackle.

# %% [markdown]
# ## 0. Colab
#
# **First, make sure to use GPU acceleration** by clicking on `"Runtime --> Change runtime --> GPU"` if you are on Colab.

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# ## 1. Data
#
# We'll take care of data loading and preprocessing for you. Just run the following cells and make sure you understand them

# %%
from tensorflow.keras.datasets import cifar10
import numpy as np

(images_train, labels_train), (images_test, labels_test) = cifar10.load_data()
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

print(images_train.shape, images_test.shape)
unique, counts = np.unique(labels_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# {0: 5000,
#  1: 5000,
#  2: 5000,
#  3: 5000,
#  4: 5000,
#  5: 5000,
#  6: 5000,
#  7: 5000,
#  8: 5000,
#  9: 5000}

# %% [markdown]
# ❗️ 50,000 images may take a long time to train: **Always start with a subsample to iterate quickly** before scaling up
#
# Below, we divide the dataset size by `reduction_factor=10`. Don't try to increase it unless we ask you too.

# %%
# Reduce size
reduction_factor = 10

idx_train =  np.random.choice(len(images_train), round(len(images_train)/reduction_factor))
idx_test =  np.random.choice(len(images_test), round(len(images_test)/reduction_factor))

images_train_small = images_train[idx_train]
images_test_small = images_test[idx_test]
labels_train_small = labels_train[idx_train]
labels_test_small = labels_test[idx_test]

print(images_train.shape, images_test.shape)
unique, counts = np.unique(labels_train_small, return_counts=True)
dict(zip(unique, counts))
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# {0: 515,
#  1: 488,
#  2: 493,
#  3: 500,
#  4: 512,
#  5: 509,
#  6: 488,
#  7: 512,
#  8: 499,
#  9: 484}

# %%
# Let's plot few images to see what they look like
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
for i in range(6):
    plt.subplot(1,6, i+1)
    img = images_train[i]
    label = labels_train[i][0]
    plt.imshow(img)
    plt.title(labels[label])

# %% [markdown]
# And, as usual,
# - we normalize the data between 0 and 1
# - we create `y` as one-hot-encoded version of `labels`

# %%
X_train = images_train / 255.
X_train_small = images_train_small / 255.
X_test = images_test / 255.
X_test_small = images_test_small / 255.

from tensorflow.keras.utils import to_categorical
y_train = to_categorical(labels_train, 10)
y_train_small = to_categorical(labels_train_small, 10)
y_test = to_categorical(labels_test, 10)
y_test_small = to_categorical(labels_test_small, 10)

# %% [markdown]
# ## 2. Iterate on your CNN architecture using your small training set
#
#
# ❓ **Question** ❓ Your turn to shine!
#
# - Define the CNN architecture of your choice in a method `initialize_model()`
# - Compile your model in a method `compile_model()`:
# - Fit it on your **small** training set **only**
# - Store the output of the fit in an `history` variable
# - Try a first model yourself, before looking at PRO TIPS below
#
# <details>
#     <summary> 🆘 PRO TIPS 🆘  </summary>
#
#
# - Do not forget to add the input shape of your data to the first layer: it has 3 colors
# - Start simple, complexify after few trials to get better results
# - The task is complex: Try at least 3 or 4 convolutions
# - Kernel size do not need to be large for such small picture resolution!
# - Add some Maxpooling (but not too much else the activation "image" will become too small)
# - Keep padding = 'same' and 'stride' = (1,1) to start with.
# - Once your model overfits, try adding some dropout layer to regularize the network. A good tip is too increase dropout strengh as you move closer to the output, so as not to overfit on your end-result
# - Images are so small, that you can use larger batch size (32 or 64) to benefit from even more GPU parallelization
# </details>

# %%
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout, BatchNormalization, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras import models
from tensorflow.keras.callbacks import EarlyStopping
def initialize_model():
    '''instanciate and return the CNN architecture of your choice with less than 150,000 params'''
    model = Sequential()
    model.add(Conv2D(16, (3, 3), strides=(1, 1), 
        padding='same', input_shape=(32, 32, 3)))
    model.add(Conv2D(16, (3, 3), strides=(1, 1), 
        padding='same'))
    model.add(Conv2D(32, (3, 3), strides=(1, 1), 
        padding='same'))
    model.add(BatchNormalization(momentum=0.3))
    model.add(Activation('selu'))
    model.add(MaxPool2D((2, 2)))
    model.add(Conv2D(64, (3, 3),  strides=(1, 1), 
        padding='same'))
    model.add(Conv2D(64, (3, 3), strides=(1, 1), 
        padding='same'))
    model.add(BatchNormalization(momentum=0.3))
    model.add(Activation('selu'))
    model.add(MaxPool2D((2, 2)))
    model.add(Flatten())
    model.add(Dropout(0.3))
    model.add(Dense(16, activation='selu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='selu'))
    model.add(Dropout(0.3))
    model.add(Dense(16, activation='selu'))
    model.add(Dense(10, activation='softmax'))
    return model
    # YOUR CODE HERE

# %%
cnn1 = initialize_model();

# %%
cnn1.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_45 (Conv2D)          (None, 32, 32, 16)        448
#
#  conv2d_46 (Conv2D)          (None, 32, 32, 16)        2320
#
#  conv2d_47 (Conv2D)          (None, 32, 32, 32)        4640
#
#  batch_normalization_18 (Bat  (None, 32, 32, 32)       128
#  chNormalization)
#
#  activation_18 (Activation)  (None, 32, 32, 32)        0
#
#  max_pooling2d_18 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_48 (Conv2D)          (None, 16, 16, 64)        18496
#
#  conv2d_49 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_19 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  activation_19 (Activation)  (None, 16, 16, 64)        0
#
#  max_pooling2d_19 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  flatten_9 (Flatten)         (None, 4096)              0
#
#  dropout_27 (Dropout)        (None, 4096)              0
#
#  dense_36 (Dense)            (None, 16)                65552
#
#  dropout_28 (Dropout)        (None, 16)                0
#
#  dense_37 (Dense)            (None, 64)                1088
#
#  dropout_29 (Dropout)        (None, 64)                0
#
#  dense_38 (Dense)            (None, 16)                1040
#
#  dense_39 (Dense)            (None, 10)                170
#
# =================================================================
# Total params: 131,066
# Trainable params: 130,874
# Non-trainable params: 192
# _________________________________________________________________

# %%
def compile_model(model):
    '''return a compiled model suited for the cifar tasks'''
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'], )
    return model
    # YOUR CODE HERE

# %%
cnn1=compile_model(cnn1)

# %%
earlystop = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=10)

# %%
history = cnn1.fit(X_train_small, y_train_small, epochs=50, batch_size=32, validation_data=(X_test_small, y_test_small), callbacks=[earlystop])
# Out:
# Epoch 1/50
# 157/157 [==============================] - 4s 19ms/step - loss: 2.5182 - accuracy: 0.1556 - val_loss: 2.0433 - val_accuracy: 0.2400
# Epoch 2/50
# 157/157 [==============================] - 3s 18ms/step - loss: 2.1709 - accuracy: 0.2010 - val_loss: 1.9252 - val_accuracy: 0.2770
# Epoch 3/50
# 157/157 [==============================] - 3s 17ms/step - loss: 2.0355 - accuracy: 0.2324 - val_loss: 1.8595 - val_accuracy: 0.3110
# Epoch 4/50
# 157/157 [==============================] - 3s 17ms/step - loss: 1.9243 - accuracy: 0.2726 - val_loss: 1.7698 - val_accuracy: 0.3470
# Epoch 5/50
# 157/157 [==============================] - 3s 16ms/step - loss: 1.8380 - accuracy: 0.2996 - val_loss: 1.7719 - val_accuracy: 0.3690
# Epoch 6/50
# 157/157 [==============================] - 3s 16ms/step - loss: 1.8048 - accuracy: 0.3230 - val_loss: 1.6662 - val_accuracy: 0.3680
# Epoch 7/50
# 157/157 [==============================] - 3s 16ms/step - loss: 1.7539 - accuracy: 0.3244 - val_loss: 1.7118 - val_accuracy: 0.3800
# Epoch 8/50
# 157/157 [==============================] - 2s 16ms/step - loss: 1.7320 - accuracy: 0.3406 - val_loss: 1.6290 - val_accuracy: 0.4100
# Epoch 9/50
# 157/157 [==============================] - 2s 16ms/step - loss: 1.6963 - accuracy: 0.3584 - val_loss: 1.5952 - val_accuracy: 0.4250
# Epoch 10/50
# 157/157 [==============================] - 2s 16ms/step - loss: 1.6422 - accuracy: 0.3760 - val_loss: 1.5559 - val_accuracy: 0.4450
# Epoch 11/50
# 157/157 [==============================] - 2s 16ms/step - loss: 1.6155 - accuracy: 0.3898 - val_loss: 1.5733 - val_accuracy: 0.4120
# Epoch 12/50
# 157/157 [==============================] - 2s 16ms/step - loss: 1.5574 - accuracy: 0.4034 - val_loss: 1.5207 - val_accuracy: 0.4530
# Epoch 13/50
# 157/157 [==============================] - 3s 16ms/step - loss: 1.5044 - accuracy: 0.4354 - val_loss: 1.5394 - val_accuracy: 0.4470
# Epoch 14/50
# 157/157 [==============================] - 3s 16ms/step - loss: 1.4661 - accuracy: 0.4402 - val_loss: 1.5264 - val_accuracy: 0.4610
# Epoch 15/50
# 157/157 [==============================] - 3s 17ms/step - loss: 1.4665 - accuracy: 0.4456 - val_loss: 1.4624 - val_accuracy: 0.4810
# Epoch 16/50
# 157/157 [==============================] - 3s 17ms/step - loss: 1.4161 - accuracy: 0.4500 - val_loss: 1.4379 - val_accuracy: 0.4660
# Epoch 17/50
# 157/157 [==============================] - 3s 16ms/step - loss: 1.3923 - accuracy: 0.4670 - val_loss: 1.4784 - val_accuracy: 0.4790
# Epoch 18/50
# 157/157 [==============================] - 3s 17ms/step - loss: 1.3837 - accuracy: 0.4652 - val_loss: 1.4223 - val_accuracy: 0.4800
# Epoch 19/50
# 157/157 [==============================] - 2s 16ms/step - loss: 1.3802 - accuracy: 0.4782 - val_loss: 1.4852 - val_accuracy: 0.4970
# Epoch 20/50
# 157/157 [==============================] - 3s 16ms/step - loss: 1.3356 - accuracy: 0.5054 - val_loss: 1.6105 - val_accuracy: 0.4600
# Epoch 21/50
# 157/157 [==============================] - 3s 16ms/step - loss: 1.3159 - accuracy: 0.4994 - val_loss: 1.4864 - val_accuracy: 0.4940
# Epoch 22/50
# 157/157 [==============================] - 3s 16ms/step - loss: 1.3075 - accuracy: 0.5086 - val_loss: 1.4260 - val_accuracy: 0.5140
# Epoch 23/50
# 157/157 [==============================] - 2s 16ms/step - loss: 1.2661 - accuracy: 0.5318 - val_loss: 1.4278 - val_accuracy: 0.4980
# Epoch 24/50
# 157/157 [==============================] - 3s 16ms/step - loss: 1.2345 - accuracy: 0.5302 - val_loss: 1.4117 - val_accuracy: 0.5120
# Epoch 25/50
# 157/157 [==============================] - 3s 17ms/step - loss: 1.2242 - accuracy: 0.5484 - val_loss: 1.3653 - val_accuracy: 0.5310
# Epoch 26/50
# 157/157 [==============================] - 3s 16ms/step - loss: 1.2108 - accuracy: 0.5446 - val_loss: 1.4458 - val_accuracy: 0.5220
# Epoch 27/50
# 157/157 [==============================] - 3s 17ms/step - loss: 1.1801 - accuracy: 0.5600 - val_loss: 1.4281 - val_accuracy: 0.5190
# Epoch 28/50
# 157/157 [==============================] - 3s 17ms/step - loss: 1.1517 - accuracy: 0.5702 - val_loss: 1.4227 - val_accuracy: 0.5100
# Epoch 29/50
# 157/157 [==============================] - 3s 16ms/step - loss: 1.1041 - accuracy: 0.5872 - val_loss: 1.3988 - val_accuracy: 0.5380
# Epoch 30/50
# 157/157 [==============================] - 3s 16ms/step - loss: 1.0933 - accuracy: 0.5992 - val_loss: 1.4549 - val_accuracy: 0.5270
# Epoch 31/50
# 157/157 [==============================] - 3s 16ms/step - loss: 1.0857 - accuracy: 0.5992 - val_loss: 1.4488 - val_accuracy: 0.5310
# Epoch 32/50
# 157/157 [==============================] - 3s 17ms/step - loss: 1.0543 - accuracy: 0.6160 - val_loss: 1.4117 - val_accuracy: 0.5260
# Epoch 33/50
# 157/157 [==============================] - 3s 16ms/step - loss: 1.0148 - accuracy: 0.6182 - val_loss: 1.4613 - val_accuracy: 0.5250
# Epoch 34/50
# 157/157 [==============================] - 3s 17ms/step - loss: 1.0033 - accuracy: 0.6254 - val_loss: 1.5478 - val_accuracy: 0.4870
# Epoch 35/50
# 157/157 [==============================] - 3s 17ms/step - loss: 0.9802 - accuracy: 0.6354 - val_loss: 1.4413 - val_accuracy: 0.5200
# Epoch 36/50
# 157/157 [==============================] - 3s 17ms/step - loss: 0.9254 - accuracy: 0.6654 - val_loss: 1.5096 - val_accuracy: 0.5240
# Epoch 37/50
# 157/157 [==============================] - 3s 17ms/step - loss: 0.9207 - accuracy: 0.6662 - val_loss: 1.4669 - val_accuracy: 0.5250
# Epoch 38/50
# 157/157 [==============================] - 3s 16ms/step - loss: 0.9011 - accuracy: 0.6714 - val_loss: 1.4622 - val_accuracy: 0.5420
# Epoch 39/50
# 157/157 [==============================] - 3s 16ms/step - loss: 0.9047 - accuracy: 0.6642 - val_loss: 1.4742 - val_accuracy: 0.5430
# Epoch 40/50
# 157/157 [==============================] - 3s 16ms/step - loss: 0.8823 - accuracy: 0.6764 - val_loss: 1.4583 - val_accuracy: 0.5350
# Epoch 41/50
# 157/157 [==============================] - 3s 17ms/step - loss: 0.8689 - accuracy: 0.6820 - val_loss: 1.5187 - val_accuracy: 0.5440
# Epoch 42/50
# 157/157 [==============================] - 3s 17ms/step - loss: 0.8470 - accuracy: 0.6898 - val_loss: 1.5296 - val_accuracy: 0.5370
# Epoch 43/50
# 157/157 [==============================] - 3s 17ms/step - loss: 0.8260 - accuracy: 0.7040 - val_loss: 1.4755 - val_accuracy: 0.5570
# Epoch 44/50
# 157/157 [==============================] - 3s 16ms/step - loss: 0.8219 - accuracy: 0.7050 - val_loss: 1.5289 - val_accuracy: 0.5530
# Epoch 45/50
# 157/157 [==============================] - 3s 16ms/step - loss: 0.7914 - accuracy: 0.7166 - val_loss: 1.5691 - val_accuracy: 0.5450
# Epoch 46/50
# 157/157 [==============================] - 3s 17ms/step - loss: 0.7696 - accuracy: 0.7214 - val_loss: 1.4864 - val_accuracy: 0.5570
# Epoch 47/50
# 157/157 [==============================] - 3s 16ms/step - loss: 0.7499 - accuracy: 0.7368 - val_loss: 1.6652 - val_accuracy: 0.5200
# Epoch 48/50
# 157/157 [==============================] - 3s 17ms/step - loss: 0.7753 - accuracy: 0.7236 - val_loss: 1.6467 - val_accuracy: 0.5260
# Epoch 49/50
# 157/157 [==============================] - 3s 17ms/step - loss: 0.7356 - accuracy: 0.7354 - val_loss: 1.5597 - val_accuracy: 0.5460
# Epoch 50/50
# 157/157 [==============================] - 3s 17ms/step - loss: 0.7421 - accuracy: 0.7326 - val_loss: 1.5108 - val_accuracy: 0.5470

# %%
# YOUR CODE HERE
score = cnn1.evaluate(X_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 1.488677978515625
# Test accuracy: 0.54830002784729

# %%
cnn1.save('CNN_CIFAR.h5')

# %%
from tensorflow.keras.models import load_model
cnn1 = load_model('CNN_CIFAR.h5')

# %% [markdown]
# ❓ **Question** ❓ Run the following function on the previous history (keep the default arguments, these are intended for future plots in the notebook).

# %%
def plot_history(history, title='', axs=None, exp_name=""):
    if axs is not None:
        ax1, ax2 = axs
    else:
        f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    
    if len(exp_name) > 0 and exp_name[0] != '_':
        exp_name = '_' + exp_name
    ax1.plot(history.history['loss'], label='train' + exp_name)
    ax1.plot(history.history['val_loss'], label='val' + exp_name)
    ax1.set_ylim(0., 2.2)
    ax1.set_title('loss')
    ax1.legend()

    ax2.plot(history.history['accuracy'], label='train accuracy'  + exp_name)
    ax2.plot(history.history['val_accuracy'], label='val accuracy'  + exp_name)
    ax2.set_ylim(0.25, 1.)
    ax2.set_title('Accuracy')
    ax2.legend()
    return (ax1, ax2)

# %%
plot_history(history)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fa06e47c090>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f9ff25a0d90>)

# %% [markdown]
# ❓ **Question** ❓ Evaluate your model on the test data and compare it with baseline. Are you satisfied with these performances ? Look at PRO TIPS above and iterate a bit if you want to improve!

# %%
# YOUR CODE HERE
y_pred = cnn1.predict(X_test, verbose=0)

# %%
# Evaluate the model on test data
score = cnn1.evaluate(X_test,y_test)
print('Test Loss : {:.4f}'.format(score[0]))
print('Test Accuracy : {:.4f}'.format(score[1]))
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 1.4887 - accuracy: 0.5483
# Test Loss : 1.4887
# Test Accuracy : 0.5483

# %% [markdown]
# ## 3. Increase data size

# %% [markdown]
# ❓ **Question** ❓ Now that your model fits on a small subsample, try to fit it on the full dataset and notice how performance increases.
#
# 🚨 **Make sure to use GPU acceleration** by clicking on `"Runtime --> Change runtime --> GPU"` if you are on Colab.
#
# 💡 Training neural network on images (in each batch) can be parallelized, and this parallelization procedure can be done on GPU.

# %%
cnn2 = initialize_model();

# %%
cnn2.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_50 (Conv2D)          (None, 32, 32, 16)        448
#
#  conv2d_51 (Conv2D)          (None, 32, 32, 16)        2320
#
#  conv2d_52 (Conv2D)          (None, 32, 32, 32)        4640
#
#  batch_normalization_20 (Bat  (None, 32, 32, 32)       128
#  chNormalization)
#
#  activation_20 (Activation)  (None, 32, 32, 32)        0
#
#  max_pooling2d_20 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_53 (Conv2D)          (None, 16, 16, 64)        18496
#
#  conv2d_54 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_21 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  activation_21 (Activation)  (None, 16, 16, 64)        0
#
#  max_pooling2d_21 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 4096)              0
#
#  dropout_30 (Dropout)        (None, 4096)              0
#
#  dense_40 (Dense)            (None, 16)                65552
#
#  dropout_31 (Dropout)        (None, 16)                0
#
#  dense_41 (Dense)            (None, 64)                1088
#
#  dropout_32 (Dropout)        (None, 64)                0
#
#  dense_42 (Dense)            (None, 16)                1040
#
#  dense_43 (Dense)            (None, 10)                170
#
# =================================================================
# Total params: 131,066
# Trainable params: 130,874
# Non-trainable params: 192
# _________________________________________________________________

# %%
def compile_model(model):
    '''return a compiled model suited for the cifar tasks'''
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'], )
    return model
    # YOUR CODE HERE

# %%
cnn2=compile_model(cnn2)

# %%
earlystop = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=10)

# %%
history = cnn2.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[earlystop])
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 28s 17ms/step - loss: 1.9806 - accuracy: 0.2780 - val_loss: 1.4647 - val_accuracy: 0.4659
# Epoch 2/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.5297 - accuracy: 0.4459 - val_loss: 1.2764 - val_accuracy: 0.5622
# Epoch 3/50
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.3390 - accuracy: 0.5230 - val_loss: 1.1440 - val_accuracy: 0.6076
# Epoch 4/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.2669 - accuracy: 0.5522 - val_loss: 1.0556 - val_accuracy: 0.6419
# Epoch 5/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.2213 - accuracy: 0.5683 - val_loss: 1.0210 - val_accuracy: 0.6489
# Epoch 6/50
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.1925 - accuracy: 0.5804 - val_loss: 1.0261 - val_accuracy: 0.6362
# Epoch 7/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.1570 - accuracy: 0.5922 - val_loss: 1.0133 - val_accuracy: 0.6546
# Epoch 8/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.1392 - accuracy: 0.6013 - val_loss: 0.9850 - val_accuracy: 0.6603
# Epoch 9/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.1176 - accuracy: 0.6095 - val_loss: 0.9810 - val_accuracy: 0.6693
# Epoch 10/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.0987 - accuracy: 0.6159 - val_loss: 0.9539 - val_accuracy: 0.6754
# Epoch 11/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.0783 - accuracy: 0.6245 - val_loss: 0.9421 - val_accuracy: 0.6721
# Epoch 12/50
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.0707 - accuracy: 0.6283 - val_loss: 0.9540 - val_accuracy: 0.6819
# Epoch 13/50
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.0522 - accuracy: 0.6332 - val_loss: 0.9217 - val_accuracy: 0.6816
# Epoch 14/50
# 1563/1563 [==============================] - 27s 18ms/step - loss: 1.0400 - accuracy: 0.6378 - val_loss: 0.9078 - val_accuracy: 0.6868
# Epoch 15/50
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.0391 - accuracy: 0.6390 - val_loss: 0.8982 - val_accuracy: 0.6957
# Epoch 16/50
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.0234 - accuracy: 0.6446 - val_loss: 0.9068 - val_accuracy: 0.6866
# Epoch 17/50
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.0135 - accuracy: 0.6451 - val_loss: 0.8901 - val_accuracy: 0.6945
# Epoch 18/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.0024 - accuracy: 0.6520 - val_loss: 0.8779 - val_accuracy: 0.6977
# Epoch 19/50
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.0009 - accuracy: 0.6529 - val_loss: 0.8862 - val_accuracy: 0.6945
# Epoch 20/50
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.9886 - accuracy: 0.6581 - val_loss: 0.8745 - val_accuracy: 0.7068
# Epoch 21/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.9798 - accuracy: 0.6614 - val_loss: 0.8661 - val_accuracy: 0.7021
# Epoch 22/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.9781 - accuracy: 0.6612 - val_loss: 0.8460 - val_accuracy: 0.7134
# Epoch 23/50
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.9649 - accuracy: 0.6640 - val_loss: 0.8763 - val_accuracy: 0.7007
# Epoch 24/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.9576 - accuracy: 0.6669 - val_loss: 0.8689 - val_accuracy: 0.7088
# Epoch 25/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.9549 - accuracy: 0.6677 - val_loss: 0.8961 - val_accuracy: 0.6955
# Epoch 26/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.9555 - accuracy: 0.6693 - val_loss: 0.8446 - val_accuracy: 0.7144
# Epoch 27/50
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.9465 - accuracy: 0.6754 - val_loss: 0.8298 - val_accuracy: 0.7154
# Epoch 28/50
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.9398 - accuracy: 0.6761 - val_loss: 0.8486 - val_accuracy: 0.7153
# Epoch 29/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.9316 - accuracy: 0.6790 - val_loss: 0.8436 - val_accuracy: 0.7116
# Epoch 30/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.9241 - accuracy: 0.6782 - val_loss: 0.8301 - val_accuracy: 0.7157
# Epoch 31/50
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.9240 - accuracy: 0.6816 - val_loss: 0.8215 - val_accuracy: 0.7226
# Epoch 32/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.9213 - accuracy: 0.6820 - val_loss: 0.8662 - val_accuracy: 0.7035
# Epoch 33/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.9166 - accuracy: 0.6855 - val_loss: 0.8376 - val_accuracy: 0.7193
# Epoch 34/50
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.9155 - accuracy: 0.6836 - val_loss: 0.8159 - val_accuracy: 0.7220
# Epoch 35/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.9077 - accuracy: 0.6871 - val_loss: 0.8414 - val_accuracy: 0.7202
# Epoch 36/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.8980 - accuracy: 0.6896 - val_loss: 0.8449 - val_accuracy: 0.7108
# Epoch 37/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.9043 - accuracy: 0.6864 - val_loss: 0.8391 - val_accuracy: 0.7156
# Epoch 38/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.8951 - accuracy: 0.6899 - val_loss: 0.8073 - val_accuracy: 0.7269
# Epoch 39/50
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.8960 - accuracy: 0.6880 - val_loss: 0.8010 - val_accuracy: 0.7305
# Epoch 40/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.8922 - accuracy: 0.6915 - val_loss: 0.8194 - val_accuracy: 0.7248
# Epoch 41/50
# 1563/1563 [==============================] - 24s 16ms/step - loss: 0.8869 - accuracy: 0.6943 - val_loss: 0.8172 - val_accuracy: 0.7258
# Epoch 42/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.8817 - accuracy: 0.6983 - val_loss: 0.8237 - val_accuracy: 0.7187
# Epoch 43/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.8814 - accuracy: 0.6952 - val_loss: 0.8052 - val_accuracy: 0.7270
# Epoch 44/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.8812 - accuracy: 0.6968 - val_loss: 0.8183 - val_accuracy: 0.7162
# Epoch 45/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.8774 - accuracy: 0.6951 - val_loss: 0.8200 - val_accuracy: 0.7216
# Epoch 46/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.8747 - accuracy: 0.6973 - val_loss: 0.8188 - val_accuracy: 0.7271
# Epoch 47/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.8715 - accuracy: 0.6993 - val_loss: 0.7874 - val_accuracy: 0.7269
# Epoch 48/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.8678 - accuracy: 0.7034 - val_loss: 0.7905 - val_accuracy: 0.7349
# Epoch 49/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.8629 - accuracy: 0.7020 - val_loss: 0.8027 - val_accuracy: 0.7302
# Epoch 50/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.8634 - accuracy: 0.7032 - val_loss: 0.8118 - val_accuracy: 0.7244

# %%
plot_history(history)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f9ff4d6d0d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f9ff4dd6850>)

# %%
# Evaluate the model on test data
score = cnn2.evaluate(X_test,y_test,verbose=0)
print('Test Loss : {:.4f}'.format(score[0]))
print('Test Accuracy : {:.4f}'.format(score[1]))
# Out:
# Test Loss : 0.8118
# Test Accuracy : 0.7244

# %% [markdown]
# ## 4. Data augmentation
#
# ☝️ It seems that adding pictures greatly improves model performance! Welcome to the Deep Learning paradigm, where big data does make a difference.
#
# To easily improve the accuracy of a model without much work, we can generate new data: the _data augmentation_. This widely used technique consists in applying little transformation to input images without changing its label, as mirroring, cropping, intensity changes, etc. The improved performance simply results from the Neural network training with more different data.
#
# The natural way to generate these new images is to apply some transformations and train the model on the original and new images. However, such procedure requires to keep all these images in memory : it can be very intensive, to the point that your computer memory cannot hold any new image (your computer might even crash).
#
# For this reason, we will augment the data **on the fly** (batch per batch), meaning that we will create new data, use them to fit the model, then delete them. Here, Keras is our friend as it provides the utils to do all this job for us. Look at the following code : the general writing can seem odd but don't be panicked: just look at the function arguments that defines the augmentation techniques that we will use and that you can check in the  [documentation](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator).

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    featurewise_center=False,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=(0.8, 1.2),
    ) 

datagen.fit(X_train)
datagen

# %%
X_augmented_iterator = datagen.flow(X_train, shuffle=False, batch_size=1)
X_augmented_iterator

# %% [markdown]
# 💡 Always visualize your data augmentation in order to double check that you can still recognize the label yourself!

# %%
import numpy as np

for i, (raw_image, augmented_image) in enumerate(zip(X_train, X_augmented_iterator)):
    _, (ax1, ax2) = plt.subplots(1, 2, figsize=(6, 2))
    ax1.imshow(raw_image)
    ax2.imshow(augmented_image[0])
    plt.show()
    
    if i > 10:
        break

# %% [markdown]
# ❗ **Remark** ❗ In this example, there is one augmented image per initial image. In fact, when your model will use `datagen.flow` in the `fit`, it will create one augmentation per epochs! Indeed, the images in the original dataset will not be provided to the optimizer, only augmented ones instead. (But because the augmentations are performed randomly, this allows both modified images and some very close of the originals).
#
# ❓ **Question** ❓ Take time to understand the cell below: Previously, we used the `validation_split` argument to let the model separate a training set from the validation one. It is not possible here as **using an image in the training set and its transformation in the validation set is considered as a data leakage**. Therefore, we have to manually define the `validation_data` with the following commands:

# %%
from tensorflow.keras.callbacks import EarlyStopping

# The model
model_aug = initialize_model()
model_aug = compile_model(model_aug)

# The data generator
X_tr = X_train[:40000]
y_tr = y_train[:40000]
X_val = X_train[40000:]
y_val = y_train[40000:]
train_flow = datagen.flow(X_tr, y_tr, batch_size=32)

# The early stopping criterion
es = EarlyStopping(patience=10)

# The fit
history_aug = model_aug.fit(train_flow, 
                        epochs=50, 
                        callbacks=[es], 
                        validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 1250/1250 [==============================] - 43s 34ms/step - loss: 2.0964 - accuracy: 0.2359 - val_loss: 1.7181 - val_accuracy: 0.3681
# Epoch 2/50
# 1250/1250 [==============================] - 42s 34ms/step - loss: 1.7694 - accuracy: 0.3481 - val_loss: 1.4725 - val_accuracy: 0.4614
# Epoch 3/50
# 1250/1250 [==============================] - 42s 34ms/step - loss: 1.6100 - accuracy: 0.4126 - val_loss: 1.3713 - val_accuracy: 0.5058
# Epoch 4/50
# 1250/1250 [==============================] - 42s 33ms/step - loss: 1.5244 - accuracy: 0.4505 - val_loss: 1.2710 - val_accuracy: 0.5383
# Epoch 5/50
# 1250/1250 [==============================] - 43s 35ms/step - loss: 1.4708 - accuracy: 0.4686 - val_loss: 1.2380 - val_accuracy: 0.5718
# Epoch 6/50
# 1250/1250 [==============================] - 43s 35ms/step - loss: 1.4331 - accuracy: 0.4852 - val_loss: 1.2293 - val_accuracy: 0.5757
# Epoch 7/50
# 1250/1250 [==============================] - 43s 34ms/step - loss: 1.4100 - accuracy: 0.4943 - val_loss: 1.1836 - val_accuracy: 0.5915
# Epoch 8/50
# 1250/1250 [==============================] - 43s 35ms/step - loss: 1.3883 - accuracy: 0.5042 - val_loss: 1.2192 - val_accuracy: 0.5765
# Epoch 9/50
# 1250/1250 [==============================] - 43s 34ms/step - loss: 1.3553 - accuracy: 0.5172 - val_loss: 1.1913 - val_accuracy: 0.5775
# Epoch 10/50
# 1250/1250 [==============================] - 43s 34ms/step - loss: 1.3401 - accuracy: 0.5263 - val_loss: 1.1052 - val_accuracy: 0.6165
# Epoch 11/50
# 1250/1250 [==============================] - 43s 34ms/step - loss: 1.3216 - accuracy: 0.5318 - val_loss: 1.1698 - val_accuracy: 0.5892
# Epoch 12/50
# 1250/1250 [==============================] - 44s 35ms/step - loss: 1.3088 - accuracy: 0.5363 - val_loss: 1.1151 - val_accuracy: 0.6153
# Epoch 13/50
# 1250/1250 [==============================] - 45s 36ms/step - loss: 1.2993 - accuracy: 0.5379 - val_loss: 1.0884 - val_accuracy: 0.6203
# Epoch 14/50
# 1250/1250 [==============================] - 43s 34ms/step - loss: 1.2867 - accuracy: 0.5454 - val_loss: 1.0640 - val_accuracy: 0.6246
# Epoch 15/50
# 1250/1250 [==============================] - 44s 35ms/step - loss: 1.2778 - accuracy: 0.5480 - val_loss: 1.1178 - val_accuracy: 0.6185
# Epoch 16/50
# 1250/1250 [==============================] - 44s 35ms/step - loss: 1.2676 - accuracy: 0.5515 - val_loss: 1.1087 - val_accuracy: 0.6197
# Epoch 17/50
# 1250/1250 [==============================] - 44s 35ms/step - loss: 1.2634 - accuracy: 0.5510 - val_loss: 1.0616 - val_accuracy: 0.6365
# Epoch 18/50
# 1250/1250 [==============================] - 44s 35ms/step - loss: 1.2532 - accuracy: 0.5561 - val_loss: 1.0206 - val_accuracy: 0.6479
# Epoch 19/50
# 1250/1250 [==============================] - 44s 35ms/step - loss: 1.2469 - accuracy: 0.5566 - val_loss: 1.0214 - val_accuracy: 0.6417
# Epoch 20/50
# 1250/1250 [==============================] - 44s 35ms/step - loss: 1.2418 - accuracy: 0.5612 - val_loss: 1.0772 - val_accuracy: 0.6288
# Epoch 21/50
# 1250/1250 [==============================] - 43s 35ms/step - loss: 1.2332 - accuracy: 0.5638 - val_loss: 0.9941 - val_accuracy: 0.6567
# Epoch 22/50
# 1250/1250 [==============================] - 43s 34ms/step - loss: 1.2188 - accuracy: 0.5729 - val_loss: 1.0750 - val_accuracy: 0.6217
# Epoch 23/50
# 1250/1250 [==============================] - 43s 35ms/step - loss: 1.2108 - accuracy: 0.5712 - val_loss: 0.9696 - val_accuracy: 0.6642
# Epoch 24/50
# 1250/1250 [==============================] - 43s 34ms/step - loss: 1.2106 - accuracy: 0.5748 - val_loss: 1.0180 - val_accuracy: 0.6447
# Epoch 25/50
# 1250/1250 [==============================] - 43s 35ms/step - loss: 1.2079 - accuracy: 0.5759 - val_loss: 1.0051 - val_accuracy: 0.6492
# Epoch 26/50
# 1250/1250 [==============================] - 43s 35ms/step - loss: 1.2078 - accuracy: 0.5745 - val_loss: 1.0136 - val_accuracy: 0.6479
# Epoch 27/50
# 1250/1250 [==============================] - 43s 35ms/step - loss: 1.1872 - accuracy: 0.5817 - val_loss: 0.9767 - val_accuracy: 0.6632
# Epoch 28/50
# 1250/1250 [==============================] - 44s 35ms/step - loss: 1.1905 - accuracy: 0.5817 - val_loss: 0.9504 - val_accuracy: 0.6722
# Epoch 29/50
# 1250/1250 [==============================] - 44s 35ms/step - loss: 1.1893 - accuracy: 0.5799 - val_loss: 1.0128 - val_accuracy: 0.6451
# Epoch 30/50
# 1250/1250 [==============================] - 43s 34ms/step - loss: 1.1923 - accuracy: 0.5804 - val_loss: 0.9611 - val_accuracy: 0.6628
# Epoch 31/50
# 1250/1250 [==============================] - 43s 34ms/step - loss: 1.1781 - accuracy: 0.5842 - val_loss: 1.0117 - val_accuracy: 0.6408
# Epoch 32/50
# 1250/1250 [==============================] - 42s 34ms/step - loss: 1.1867 - accuracy: 0.5805 - val_loss: 1.0211 - val_accuracy: 0.6535
# Epoch 33/50
# 1250/1250 [==============================] - 42s 34ms/step - loss: 1.1724 - accuracy: 0.5868 - val_loss: 0.9525 - val_accuracy: 0.6694
# Epoch 34/50
# 1250/1250 [==============================] - 42s 34ms/step - loss: 1.1787 - accuracy: 0.5847 - val_loss: 0.9986 - val_accuracy: 0.6573
# Epoch 35/50
# 1250/1250 [==============================] - 43s 34ms/step - loss: 1.1827 - accuracy: 0.5807 - val_loss: 0.9871 - val_accuracy: 0.6585
# Epoch 36/50
# 1250/1250 [==============================] - 42s 34ms/step - loss: 1.1613 - accuracy: 0.5897 - val_loss: 0.9916 - val_accuracy: 0.6527
# Epoch 37/50
# 1250/1250 [==============================] - 42s 34ms/step - loss: 1.1603 - accuracy: 0.5912 - val_loss: 0.9466 - val_accuracy: 0.6717
# Epoch 38/50
# 1250/1250 [==============================] - 42s 34ms/step - loss: 1.1617 - accuracy: 0.5921 - val_loss: 0.9512 - val_accuracy: 0.6763
# Epoch 39/50
# 1250/1250 [==============================] - 43s 34ms/step - loss: 1.1612 - accuracy: 0.5924 - val_loss: 0.9432 - val_accuracy: 0.6752
# Epoch 40/50
# 1250/1250 [==============================] - 44s 35ms/step - loss: 1.1479 - accuracy: 0.5955 - val_loss: 0.9212 - val_accuracy: 0.6856
# Epoch 41/50
# 1250/1250 [==============================] - 44s 35ms/step - loss: 1.1521 - accuracy: 0.5932 - val_loss: 0.9788 - val_accuracy: 0.6651
# Epoch 42/50
# 1250/1250 [==============================] - 43s 34ms/step - loss: 1.1548 - accuracy: 0.5942 - val_loss: 0.9062 - val_accuracy: 0.6855
# Epoch 43/50
# 1250/1250 [==============================] - 44s 35ms/step - loss: 1.1505 - accuracy: 0.5943 - val_loss: 0.9771 - val_accuracy: 0.6692
# Epoch 44/50
# 1250/1250 [==============================] - 43s 34ms/step - loss: 1.1410 - accuracy: 0.5999 - val_loss: 0.9414 - val_accuracy: 0.6751
# Epoch 45/50
# 1250/1250 [==============================] - 43s 35ms/step - loss: 1.1522 - accuracy: 0.5946 - val_loss: 0.9561 - val_accuracy: 0.6703
# Epoch 46/50
# 1250/1250 [==============================] - 43s 34ms/step - loss: 1.1472 - accuracy: 0.5942 - val_loss: 0.9624 - val_accuracy: 0.6719
# Epoch 47/50
# 1250/1250 [==============================] - 43s 34ms/step - loss: 1.1448 - accuracy: 0.5997 - val_loss: 0.9483 - val_accuracy: 0.6798
# Epoch 48/50
# 1250/1250 [==============================] - 44s 35ms/step - loss: 1.1320 - accuracy: 0.6002 - val_loss: 0.9203 - val_accuracy: 0.6809
# Epoch 49/50
# 1250/1250 [==============================] - 43s 35ms/step - loss: 1.1361 - accuracy: 0.5993 - val_loss: 0.9056 - val_accuracy: 0.6911
# Epoch 50/50
# 1250/1250 [==============================] - 44s 35ms/step - loss: 1.1341 - accuracy: 0.5997 - val_loss: 0.9144 - val_accuracy: 0.6827

# %% [markdown]
# ❗️❗️ Remark ❗️❗️: The training can be quite long here. Don't hesitate to go to the next exercise and gome back once in a while to finish the last questions
#
# ❓ **Question** ❓ Now, let's plot the previous and current run histories. What do you think of the data augmentation?

# %%
#Visualize the model's training progress using the stats stored in the history object.
#we experience a slight fall in accuracy
import pandas as pd
hist = pd.DataFrame(history_aug.history)
hist['epoch'] = history_aug.epoch
hist.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 45  1.147187  0.594225  0.962371        0.6719     45
# 46  1.144783  0.599700  0.948317        0.6798     46
# 47  1.132021  0.600175  0.920341        0.6809     47
# 48  1.136070  0.599300  0.905583        0.6911     48
# 49  1.134091  0.599700  0.914353        0.6827     49

# %%
plot_history(history_aug)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f9ff24a64d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa06e0c1690>)

# %%
# Evaluate the model on test data
score = model_aug.evaluate(X_test,y_test,verbose=0)
print('Test Loss : {:.4f}'.format(score[0]))
print('Test Accuracy : {:.4f}'.format(score[1]))
# Out:
# Test Loss : 0.9301
# Test Accuracy : 0.6792

# %% [markdown]
# 💡 Data augmentation may not improve your performance easily. It strongly depends on the model architecture you used, the learning rate, the type of augmentation chosen, etc...Image classification is an art that takes lots of practice to master!
#
# 🚨 **Don't spend too much time now trying to finetune your model - you have other interesting challenge ahead**.
#
# 📚 [here is a good example of solution for future reference](https://machinelearningmastery.com/how-to-develop-a-cnn-from-scratch-for-cifar-10-photo-classification/). They manage to get about 80% accuracy

# %% [markdown]
# ### 🏁 Congratulation 🏁
